# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
    Dropout,
    Flatten,
    Dense
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import joblib

DATA_PATH = "../preprocessed_audio_data"
MODEL_PATH = "../models/speech_model_trained.keras"

print("Loading data...")

X = np.load(os.path.join(DATA_PATH, "X.npy"))
y = np.load(os.path.join(DATA_PATH, "y.npy"))

print("X shape:", X.shape)
print("y shape:", y.shape)

print("Original y shape:", y.shape)
# Out:
# Loading data...
# X shape: (1440, 128, 128, 1)
# y shape: (1440, 8)
# Original y shape: (1440, 8)

# %%
# If y is already one-hot encoded
if len(y.shape) == 2:
    y_labels = np.argmax(y, axis=1)
else:
    y_labels = y

label_encoder = LabelEncoder()
y_labels = label_encoder.fit_transform(y_labels)

print("y_labels shape (after fix):", y_labels.shape)
# Out:
# y_labels shape (after fix): (1440,)

# %%
# Split using 1D labels
X_train, X_val, y_train_labels, y_val_labels = train_test_split(
    X,
    y_labels,
    test_size=0.2,
    random_state=42,
    stratify=y_labels
)

# Convert back to one-hot for training
NUM_CLASSES = len(np.unique(y_labels))

y_train = to_categorical(y_train_labels, NUM_CLASSES)
y_val = to_categorical(y_val_labels, NUM_CLASSES)

print("Split successful.")
print("Train labels shape:", y_train.shape)
print("Val labels shape:", y_val.shape)
# Out:
# Split successful.
# Train labels shape: (1152, 8)
# Val labels shape: (288, 8)

# %%
# Model
model = Sequential([
    Input(shape=(128, 128, 1)),

    tf.keras.layers.RandomTranslation(0.1, 0.1),
    tf.keras.layers.RandomZoom(0.1),

    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.3),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

callbacks = [
    EarlyStopping(patience=8, restore_best_weights=True),
    ReduceLROnPlateau(patience=4)
]

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_translation_5            │ (None, 128, 128, 1)    │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom_5 (RandomZoom)      │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 126, 126, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 61, 61, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │     6,422,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,518,408 (24.87 MB)
#  Trainable params: 6,517,960 (24.86 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 281ms/step - accuracy: 0.1606 - loss: 5.8160 - val_accuracy: 0.1354 - val_loss: 24.9670 - learning_rate: 0.0010
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - accuracy: 0.1580 - loss: 2.0663 - val_accuracy: 0.1354 - val_loss: 35.4611 - learning_rate: 0.0010
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 271ms/step - accuracy: 0.1701 - loss: 2.0305 - val_accuracy: 0.1354 - val_loss: 35.7863 - learning_rate: 0.0010
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.1797 - loss: 2.0336 - val_accuracy: 0.1354 - val_loss: 34.6619 - learning_rate: 0.0010
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 0.1641 - loss: 2.0340 - val_accuracy: 0.1354 - val_loss: 31.9436 - learning_rate: 0.0010
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - accuracy: 0.1667 - loss: 2.0383 - val_accuracy: 0.1354 - val_loss: 29.1006 - learning_rate: 1.0000e-04
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - accuracy: 0.1632 - loss: 2.0103 - val_accuracy: 0.1424 - val_loss: 25.3602 - learning_rate: 1.0000e-04
# Epoch 8/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.1693 - loss: 1.9994 - val_accuracy: 0.1944 - val_loss: 22.1055 - learning_rate: 1.0000e-04
# Epoch 9/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.1797 - loss: 2.0126 - val_accuracy: 0.2569 - val_loss: 20.0429 - learning_rate: 1.0000e-04
# Epoch 10/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.1719 - loss: 2.0038 - val_accuracy: 0.2604 - val_loss: 18.4187 - learning_rate: 1.0000e-04
# Epoch 11/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - accuracy: 0.1606 - loss: 2.0071 - val_accuracy: 0.2465 - val_loss: 16.5093 - learning_rate: 1.0000e-04
# Epoch 12/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.1727 - loss: 1.9922 - val_accuracy: 0.2361 - val_loss: 14.6000 - learning_rate: 1.0000e-04
# Epoch 13/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - accuracy: 0.1667 - loss: 1.9917 - val_accuracy: 0.2361 - val_loss: 12.1103 - learning_rate: 1.0000e-04
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.1823 - loss: 1.9852 - val_accuracy: 0.2431 - val_loss: 8.6038 - learning_rate: 1.0000e-04
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.1788 - loss: 1.9853 - val_accuracy: 0.2188 - val_loss: 6.1404 - learning_rate: 1.0000e-04
# Epoch 16/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.1727 - loss: 1.9955 - val_accuracy: 0.2188 - val_loss: 4.1072 - learning_rate: 1.0000e-04
# Epoch 17/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.1675 - loss: 1.9888 - val_accuracy: 0.2257 - val_loss: 2.7185 - learning_rate: 1.0000e-04
# Epoch 18/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 271ms/step - accuracy: 0.1849 - loss: 1.9854 - val_accuracy: 0.2049 - val_loss: 2.2125 - learning_rate: 1.0000e-04
# Epoch 19/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - accuracy: 0.1762 - loss: 1.9913 - val_accuracy: 0.2118 - val_loss: 2.0053 - learning_rate: 1.0000e-04
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 263ms/step - accuracy: 0.1736 - loss: 1.9825 - val_accuracy: 0.2153 - val_loss: 1.9445 - learning_rate: 1.0000e-04
# Epoch 21/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.1901 - loss: 1.9680 - val_accuracy: 0.1979 - val_loss: 1.9396 - learning_rate: 1.0000e-04
# Epoch 22/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.1727 - loss: 1.9995 - val_accuracy: 0.2743 - val_loss: 1.8993 - learning_rate: 1.0000e-04
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.2014 - loss: 1.9468 - val_accuracy: 0.2569 - val_loss: 1.8949 - learning_rate: 1.0000e-04
# Epoch 24/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - accuracy: 0.2153 - loss: 1.9439 - val_accuracy: 0.2812 - val_loss: 1.8688 - learning_rate: 1.0000e-04
# Epoch 25/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.2040 - loss: 1.9313 - val_accuracy: 0.2708 - val_loss: 1.8580 - learning_rate: 1.0000e-04
# Epoch 26/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.2127 - loss: 1.9386 - val_accuracy: 0.2639 - val_loss: 1.8406 - learning_rate: 1.0000e-04
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.2222 - loss: 1.9219 - val_accuracy: 0.2500 - val_loss: 1.8485 - learning_rate: 1.0000e-04
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.2326 - loss: 1.9180 - val_accuracy: 0.2708 - val_loss: 1.8375 - learning_rate: 1.0000e-04
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.2214 - loss: 1.9239 - val_accuracy: 0.2708 - val_loss: 1.8819 - learning_rate: 1.0000e-04
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 0.2387 - loss: 1.9181 - val_accuracy: 0.2674 - val_loss: 1.8699 - learning_rate: 1.0000e-04
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 0.2153 - loss: 1.9150 - val_accuracy: 0.2743 - val_loss: 1.8529 - learning_rate: 1.0000e-04
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.2387 - loss: 1.9047 - val_accuracy: 0.3229 - val_loss: 1.8243 - learning_rate: 1.0000e-04
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.2248 - loss: 1.9082 - val_accuracy: 0.3194 - val_loss: 1.8207 - learning_rate: 1.0000e-04
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - accuracy: 0.2448 - loss: 1.8745 - val_accuracy: 0.3021 - val_loss: 1.8550 - learning_rate: 1.0000e-04
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.2457 - loss: 1.8908 - val_accuracy: 0.3194 - val_loss: 1.8114 - learning_rate: 1.0000e-04
# Epoch 36/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.2491 - loss: 1.8751 - val_accuracy: 0.3160 - val_loss: 1.8596 - learning_rate: 1.0000e-04
# Epoch 37/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.2257 - loss: 1.8943 - val_accuracy: 0.3507 - val_loss: 1.8197 - learning_rate: 1.0000e-04
# Epoch 38/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 270ms/step - accuracy: 0.2405 - loss: 1.8800 - val_accuracy: 0.3507 - val_loss: 1.8118 - learning_rate: 1.0000e-04
# Epoch 39/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.2352 - loss: 1.8858 - val_accuracy: 0.3542 - val_loss: 1.7898 - learning_rate: 1.0000e-04
# Epoch 40/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.2561 - loss: 1.8331 - val_accuracy: 0.3646 - val_loss: 1.7669 - learning_rate: 1.0000e-04
# Epoch 41/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.2648 - loss: 1.8530 - val_accuracy: 0.3403 - val_loss: 1.8274 - learning_rate: 1.0000e-04
# Epoch 42/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - accuracy: 0.2378 - loss: 1.8759 - val_accuracy: 0.3194 - val_loss: 1.7888 - learning_rate: 1.0000e-04
# Epoch 43/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - accuracy: 0.2648 - loss: 1.8441 - val_accuracy: 0.3125 - val_loss: 1.8822 - learning_rate: 1.0000e-04
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.2595 - loss: 1.8443 - val_accuracy: 0.3125 - val_loss: 1.7869 - learning_rate: 1.0000e-04
# Epoch 45/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 0.2656 - loss: 1.8213 - val_accuracy: 0.3438 - val_loss: 1.7538 - learning_rate: 1.0000e-05
# Epoch 46/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 262ms/step - accuracy: 0.2613 - loss: 1.8220 - val_accuracy: 0.3576 - val_loss: 1.7485 - learning_rate: 1.0000e-05
# Epoch 47/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 262ms/step - accuracy: 0.2648 - loss: 1.8148 - val_accuracy: 0.3576 - val_loss: 1.7441 - learning_rate: 1.0000e-05
# Epoch 48/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - accuracy: 0.2804 - loss: 1.8172 - val_accuracy: 0.3542 - val_loss: 1.7456 - learning_rate: 1.0000e-05
# Epoch 49/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 0.2535 - loss: 1.8289 - val_accuracy: 0.3542 - val_loss: 1.7511 - learning_rate: 1.0000e-05
# Epoch 50/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - accuracy: 0.2839 - loss: 1.8216 - val_accuracy: 0.3576 - val_loss: 1.7591 - learning_rate: 1.0000e-05

# %%
os.makedirs("../models", exist_ok=True)

model.save(MODEL_PATH)
joblib.dump(label_encoder, "../models/label_encoder.pkl")

print("Training complete.")
print("Model saved to:", MODEL_PATH)
# Out:
# Training complete.
# Model saved to: ../models/speech_model_trained.keras
