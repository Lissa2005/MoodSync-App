# %%
import os
import joblib
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
    Dropout,
    Flatten,
    Dense
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import joblib

# Paths
DATA_PATH = "../preprocessed_audio_data"
MODEL_PATH = "../models/speech_model_trained_v.keras"

print("Loading data...")

# Load Data
X = np.load(os.path.join(DATA_PATH, "X.npy"))
y = np.load(os.path.join(DATA_PATH, "y.npy"))

label_encoder = joblib.load(
    os.path.join(DATA_PATH, "label_encoder.pkl"))

print("X shape:", X.shape)
print("y shape:", y.shape)

print("Original y shape:", y.shape)
# Out:
# Loading data...
# X shape: (1440, 128, 128, 1)
# y shape: (1440, 8)
# Original y shape: (1440, 8)

# %%
# If y is already one-hot encoded
if len(y.shape) == 2:
    y_labels = np.argmax(y, axis=1)
else:
    y_labels = y

# Check class distribution
unique, counts = np.unique(y_labels, return_counts=True)
print("Class distribution:", dict(zip(unique, counts)))
# Out:
# Class distribution: {np.int64(0): np.int64(192), np.int64(1): np.int64(192), np.int64(2): np.int64(192), np.int64(3): np.int64(192), np.int64(4): np.int64(192), np.int64(5): np.int64(96), np.int64(6): np.int64(192), np.int64(7): np.int64(192)}

# %%
# Split using 1D labels
X_train, X_val, y_train_labels, y_val_labels = train_test_split(
    X,
    y_labels,
    test_size=0.2,
    random_state=42,
    stratify=y_labels
)

# Convert back to one-hot for training
NUM_CLASSES = len(np.unique(y_labels))

print("Number of classes:", NUM_CLASSES)
print("Unique labels:", np.unique(y_labels))

y_train = to_categorical(y_train_labels, NUM_CLASSES)
y_val = to_categorical(y_val_labels, NUM_CLASSES)

print("Split successful.")
print("Train labels shape:", y_train.shape)
print("Val labels shape:", y_val.shape)
# Out:
# Number of classes: 8
# Unique labels: [0 1 2 3 4 5 6 7]
# Split successful.
# Train labels shape: (1152, 8)
# Val labels shape: (288, 8)

# %%
# Class Weights

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_labels),
    y=y_labels
)

class_weights = dict(enumerate(class_weights_array))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: np.float64(0.9375), 1: np.float64(0.9375), 2: np.float64(0.9375), 3: np.float64(0.9375), 4: np.float64(0.9375), 5: np.float64(1.875), 6: np.float64(0.9375), 7: np.float64(0.9375)}

# %%
# Model
model = Sequential([
    Input(shape=(128, 128, 1)),

    Conv2D(32, (3,3), activation='relu', padding='same'),
    Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Callbacks
callbacks = [
    EarlyStopping(patience=8, restore_best_weights=True),
    ReduceLROnPlateau(patience=4)
]

# Train
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     8,388,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,678,248 (33.10 MB)
#  Trainable params: 8,677,800 (33.10 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 380ms/step - accuracy: 0.1467 - loss: 6.5085 - val_accuracy: 0.1319 - val_loss: 16.1204 - learning_rate: 0.0010
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.1571 - loss: 2.0890 - val_accuracy: 0.1319 - val_loss: 34.0671 - learning_rate: 0.0010
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.1311 - loss: 2.0762 - val_accuracy: 0.1319 - val_loss: 34.1820 - learning_rate: 0.0010
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.1267 - loss: 2.0751 - val_accuracy: 0.1319 - val_loss: 33.2114 - learning_rate: 0.0010
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 440ms/step - accuracy: 0.1372 - loss: 2.0841 - val_accuracy: 0.1319 - val_loss: 24.0546 - learning_rate: 0.0010
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 439ms/step - accuracy: 0.1389 - loss: 2.0721 - val_accuracy: 0.1424 - val_loss: 17.5539 - learning_rate: 1.0000e-04
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 444ms/step - accuracy: 0.1380 - loss: 2.0743 - val_accuracy: 0.1493 - val_loss: 11.1277 - learning_rate: 1.0000e-04
# Epoch 8/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 429ms/step - accuracy: 0.1363 - loss: 2.0762 - val_accuracy: 0.1493 - val_loss: 5.6387 - learning_rate: 1.0000e-04
# Epoch 9/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.1363 - loss: 2.0736 - val_accuracy: 0.1215 - val_loss: 2.9197 - learning_rate: 1.0000e-04
# Epoch 10/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 375ms/step - accuracy: 0.1372 - loss: 2.0749 - val_accuracy: 0.1354 - val_loss: 2.2669 - learning_rate: 1.0000e-04
# Epoch 11/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.1380 - loss: 2.0717 - val_accuracy: 0.1215 - val_loss: 2.1239 - learning_rate: 1.0000e-04
# Epoch 12/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 375ms/step - accuracy: 0.1363 - loss: 2.0737 - val_accuracy: 0.1528 - val_loss: 2.0949 - learning_rate: 1.0000e-04
# Epoch 13/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.1337 - loss: 2.0779 - val_accuracy: 0.1493 - val_loss: 2.0881 - learning_rate: 1.0000e-04
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 375ms/step - accuracy: 0.1380 - loss: 2.0724 - val_accuracy: 0.1458 - val_loss: 2.0884 - learning_rate: 1.0000e-04
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.1406 - loss: 2.0674 - val_accuracy: 0.1424 - val_loss: 2.0911 - learning_rate: 1.0000e-04
# Epoch 16/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.1345 - loss: 2.0762 - val_accuracy: 0.1389 - val_loss: 2.0866 - learning_rate: 1.0000e-04
# Epoch 17/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.1406 - loss: 2.0690 - val_accuracy: 0.1389 - val_loss: 2.0853 - learning_rate: 1.0000e-04
# Epoch 18/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.1389 - loss: 2.0702 - val_accuracy: 0.1389 - val_loss: 2.0849 - learning_rate: 1.0000e-04
# Epoch 19/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.1398 - loss: 2.0709 - val_accuracy: 0.1389 - val_loss: 2.0804 - learning_rate: 1.0000e-04
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.1389 - loss: 2.0690 - val_accuracy: 0.1354 - val_loss: 2.0838 - learning_rate: 1.0000e-04
# Epoch 21/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.1372 - loss: 2.0703 - val_accuracy: 0.1389 - val_loss: 2.0715 - learning_rate: 1.0000e-04
# Epoch 22/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.1415 - loss: 2.0647 - val_accuracy: 0.1840 - val_loss: 2.0500 - learning_rate: 1.0000e-04
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.1797 - loss: 2.0392 - val_accuracy: 0.1736 - val_loss: 2.0571 - learning_rate: 1.0000e-04
# Epoch 24/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.1884 - loss: 2.0277 - val_accuracy: 0.2257 - val_loss: 2.0076 - learning_rate: 1.0000e-04
# Epoch 25/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.1745 - loss: 2.0200 - val_accuracy: 0.2188 - val_loss: 2.0063 - learning_rate: 1.0000e-04
# Epoch 26/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.1849 - loss: 2.0138 - val_accuracy: 0.2292 - val_loss: 1.9959 - learning_rate: 1.0000e-04
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.1936 - loss: 1.9957 - val_accuracy: 0.2257 - val_loss: 1.9905 - learning_rate: 1.0000e-04
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.1858 - loss: 2.0022 - val_accuracy: 0.2292 - val_loss: 1.9892 - learning_rate: 1.0000e-04
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.1884 - loss: 1.9849 - val_accuracy: 0.2326 - val_loss: 1.9912 - learning_rate: 1.0000e-04
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.1910 - loss: 1.9786 - val_accuracy: 0.2361 - val_loss: 1.9783 - learning_rate: 1.0000e-04
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.1875 - loss: 1.9681 - val_accuracy: 0.2361 - val_loss: 1.9773 - learning_rate: 1.0000e-04
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 376ms/step - accuracy: 0.1944 - loss: 1.9733 - val_accuracy: 0.2465 - val_loss: 1.9755 - learning_rate: 1.0000e-04
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 376ms/step - accuracy: 0.1988 - loss: 1.9526 - val_accuracy: 0.2535 - val_loss: 1.9768 - learning_rate: 1.0000e-04
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.2135 - loss: 1.9557 - val_accuracy: 0.2396 - val_loss: 1.9805 - learning_rate: 1.0000e-04
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.1936 - loss: 1.9543 - val_accuracy: 0.2326 - val_loss: 1.9850 - learning_rate: 1.0000e-04
# Epoch 36/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.1979 - loss: 1.9489 - val_accuracy: 0.2431 - val_loss: 1.9706 - learning_rate: 1.0000e-04
# Epoch 37/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 376ms/step - accuracy: 0.1910 - loss: 1.9503 - val_accuracy: 0.2361 - val_loss: 1.9689 - learning_rate: 1.0000e-04
# Epoch 38/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.2005 - loss: 1.9432 - val_accuracy: 0.2465 - val_loss: 1.9619 - learning_rate: 1.0000e-04
# Epoch 39/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.2075 - loss: 1.9237 - val_accuracy: 0.2396 - val_loss: 1.9578 - learning_rate: 1.0000e-04
# Epoch 40/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.2092 - loss: 1.9199 - val_accuracy: 0.2361 - val_loss: 1.9619 - learning_rate: 1.0000e-04
# Epoch 41/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.2101 - loss: 1.9280 - val_accuracy: 0.2431 - val_loss: 1.9617 - learning_rate: 1.0000e-04
# Epoch 42/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.2109 - loss: 1.9191 - val_accuracy: 0.2465 - val_loss: 1.9542 - learning_rate: 1.0000e-04
# Epoch 43/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.2005 - loss: 1.9266 - val_accuracy: 0.2639 - val_loss: 1.9606 - learning_rate: 1.0000e-04
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.2257 - loss: 1.9137 - val_accuracy: 0.2465 - val_loss: 1.9372 - learning_rate: 1.0000e-04
# Epoch 45/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.2127 - loss: 1.9085 - val_accuracy: 0.2326 - val_loss: 1.9304 - learning_rate: 1.0000e-04
# Epoch 46/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 373ms/step - accuracy: 0.2153 - loss: 1.9111 - val_accuracy: 0.2465 - val_loss: 1.9330 - learning_rate: 1.0000e-04
# Epoch 47/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.2431 - loss: 1.8820 - val_accuracy: 0.2535 - val_loss: 1.9244 - learning_rate: 1.0000e-04
# Epoch 48/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.2335 - loss: 1.8924 - val_accuracy: 0.2812 - val_loss: 1.9568 - learning_rate: 1.0000e-04
# Epoch 49/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.2604 - loss: 1.8544 - val_accuracy: 0.3333 - val_loss: 1.9069 - learning_rate: 1.0000e-04
# Epoch 50/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 375ms/step - accuracy: 0.2552 - loss: 1.8153 - val_accuracy: 0.2812 - val_loss: 1.9005 - learning_rate: 1.0000e-04

# %%
os.makedirs("../models", exist_ok=True)

model.save(MODEL_PATH)
joblib.dump(label_encoder, "../models/label_encoder.pkl")

print("Training complete.")
print("Model saved to:", MODEL_PATH)
# Out:
# Training complete.
# Model saved to: ../models/speech_model_trained.keras

# %%
# Check prediction distribution
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

unique_pred, counts_pred = np.unique(y_pred_classes, return_counts=True)
print("Prediction distribution:", dict(zip(unique, counts)))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step
# Prediction distribution: {np.int64(0): np.int64(192), np.int64(1): np.int64(192), np.int64(2): np.int64(192), np.int64(3): np.int64(192), np.int64(4): np.int64(192), np.int64(5): np.int64(96), np.int64(6): np.int64(192), np.int64(7): np.int64(192)}
